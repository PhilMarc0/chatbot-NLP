# %%
# !pip install -q transformers==4.4.2

# %%
import torch
torch.__version__
# Out:
# '2.1.0+cpu'

# %%
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# Out:
# Looking in links: https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# ...
#   Running setup.py clean for torch-scatter
# Failed to build torch-scatter
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\aaren\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\aaren\\AppData\\Local\\Temp\\pip-install-bktoakq2\\torch-scatter_bcac690b4f2b40e89a9f98e9b0908f6c\\setup.py'"'"'; __file__='"'"'C:\\Users\\aaren\\AppData\\Local\\Temp\\pip-install-bktoakq2\\torch-scatter_bcac690b4f2b40e89a9f98e9b0908f6c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\aaren\AppData\Local\Temp\pip-wheel-56d0jy4c'
# ...

# %%
#IMPORT PIPELINE
from transformers import pipeline
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core._multiarray_umath failed to import
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.umath failed to import
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 #IMPORT PIPELINE
# ----> 2 from transformers import pipeline
#       3 import pandas as pd
#
# ...

# %%
tqa = pipeline(task="table-question-answering", 
               model="google/tapas-base-finetuned-wtq")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 tqa = pipeline(task="table-question-answering",
#       2                model="google/tapas-base-finetuned-wtq")
#
# NameError: name 'pipeline' is not defined

# %%
pip install pymupdf

# %%
import os

os.chdir('C:/Users/aaren/Anaconda3')

# %%
pwd()
# Out:
# 'C:\\Users\\aaren\\Anaconda3'

# %%
import fitz

# Open the PDF file
doc = fitz.open("VM0007-REDDMF_v1.6.pdf")

# Iterate over all pages
for page_number in range(doc.page_count):
    # Get the current page
    page = doc[page_number]

    # Extract text from the page
    text = page.get_text("text")

    # Print the extracted text
    print("Page", page_number + 1, "text:")
    print(text)
# Out:
# Page 1 text:
#
#
#
#
#
#
# VCS Methodology
#
#
# VM0007
# REDD+ Methodology Framework (REDD+ MF)
#
#
#
#
#
#
#
#
#
#
#
# Version 1.6
# 08 September 2020
#
#
#
#
# Sectoral Scope 14
#
# Page 2 text:
# VM0007, Version 1.6
# Sectoral Scope 14
#
# REDD+MF - 2
#
#
# Methodology developed by:
#
#
#
#
#
#
# Revision to include project activities on peatlands (version 1.5 of this methodology) prepared by Permian
# Global, Silvestrum and Greifswald University
#
#
#
#
# Revision to include tidal wetland restoration and conservation activities (version 1.6 of this methodology)
# prepared by Silvestrum Climate Associates and Restore America’s Estuaries
# This methodology was revised to include tidal wetland restoration and conservation activities with support
# from the Commission for Environmental Cooperation, The Curtis and Edith Munson Foundation, The
# Ocean Foundation, Conservation International, Blue Ventures, and The Nature Conservancy. Restore
# ...

# %%
def answer_question(document, question):
    # Prepare the context for the model
    context = f"Document: {document}\n\nQuestion: {question}"
    # Use the model to answer the question
    answer = qa_pipeline(context, question)
    return answer

# %%
def main():
    document = "Your preprocessed VM0007 document text goes here."
    while True:
        question = input("Ask a question or type 'exit' to quit: ")
        if question.lower() == "exit":
            break
        answer = answer_question(document, question)
        print("Answer:", answer)

if __name__ == "__main__":
    main()
# Out:
# Ask a question or type 'exit' to quit: "Summarise this text for me"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 10>()
#       8         print("Answer:", answer)
#      10 if __name__ == "__main__":
# ---> 11     main()
#
# Input In [11], in main()
#       5 if question.lower() == "exit":
#       6     break
# ----> 7 answer = answer_question(document, question)
#       8 print("Answer:", answer)
#
# Input In [10], in answer_question(document, question)
#       3 context = f"Document: {document}\n\nQuestion: {question}"
#       4 # Use the model to answer the question
# ----> 5 answer = qa_pipeline(context, question)
#       6 return answer
#
# NameError: name 'qa_pipeline' is not defined
